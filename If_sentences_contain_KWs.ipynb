# %% [markdown]
# <a href="https://colab.research.google.com/github/dragonfly-lab/Story/blob/main/If_sentences_contain_KWs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df_page = pd.read_excel("blog.xlsx")

# %%
df_country = pd.read_excel("Countries.xlsx")

# %%
display(df_page)
# Out:
#                                           Original Url  Status Code Status  \
# 0    https://immigrationlawyers-london.com/blog/set...          200     OK
# 1    https://immigrationlawyers-london.com/blog/bre...          200     OK
# 2    https://immigrationlawyers-london.com/blog/per...          200     OK
# 3    https://immigrationlawyers-london.com/blog/com...          200     OK
# 4    https://immigrationlawyers-london.com/blog/wor...          200     OK
# ..                                                 ...          ...    ...
# 685  https://immigrationlawyers-london.com/blog/eng...          200     OK
# 686  https://immigrationlawyers-london.com/blog/glo...          200     OK
# 687  https://immigrationlawyers-london.com/blog/rec...          200     OK
# 688  https://immigrationlawyers-london.com/blog/uk-...          200     OK
# 689  https://immigrationlawyers-london.com/blog/uk-...          200     OK
#
#                                                Title 1  \
# ...

# %%
display(df_country)
# Out:
#         Countries
# 0       Argentina
# 1       Australia
# 2      Australian
# 3         Austria
# 4         Belgium
# ..            ...
# 65       Thailand
# 66         Turkey
# 67            UAE
# 68  United States
# 69        Vietnam
#
# [70 rows x 1 columns]

# %%
df_page["Contains keyword"] = ""

# %%
# interate throught row of df_page
for i, row in df_page.iterrows():
  # interate through row of df_country
  for j, country in df_country.iterrows():
    # check if keyword is in the "Title" column of df_pages
    if country['Countries'].lower() in row['Title 1'].lower():
      # add "Yes" to the corresponding cell in df_pages
      df_page.at[i, "Contains keyword"] = "Yes" 
      break
display(df_page)
# Out:
#                                           Original Url  Status Code Status  \
# 0    https://immigrationlawyers-london.com/blog/set...          200     OK
# 1    https://immigrationlawyers-london.com/blog/bre...          200     OK
# 2    https://immigrationlawyers-london.com/blog/per...          200     OK
# 3    https://immigrationlawyers-london.com/blog/com...          200     OK
# 4    https://immigrationlawyers-london.com/blog/wor...          200     OK
# ..                                                 ...          ...    ...
# 685  https://immigrationlawyers-london.com/blog/eng...          200     OK
# 686  https://immigrationlawyers-london.com/blog/glo...          200     OK
# 687  https://immigrationlawyers-london.com/blog/rec...          200     OK
# 688  https://immigrationlawyers-london.com/blog/uk-...          200     OK
# 689  https://immigrationlawyers-london.com/blog/uk-...          200     OK
#
#                                                Title 1  \
# ...

# %%
df_page.to_excel('Global mobility pages.xlsx',index=False)
